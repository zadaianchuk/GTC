# %% [markdown]
# #### Questions 2
#
# 1. What is neurovascular coupling?
# > Link between NA and vascular processes.
#
# 2. Which physical effect(s), and which time-constants are most important for f-MRI?
# > $T2^*$, spin dephasing
#
# 3. What is the natural MR-contrast agent in our blood?
# > $HbR$
#
# 4. Which physiological effects determine the BOLD signal change, and how?
# > - consumption of oxygen during blood flow.
# > - blood flow, that flushed out the $HbR$ during NA
# > - blood volume. How???
# > - dilitation. What is it? How???
#
# 5. Can you draw the hemodynamic response function? Explain 1st and 2nd phase?
# > <img  src="images/q3g2.png"width=400/>
# > - first drop due to consumption of oxygen and bigger concentration of $HbR$
# > - than increase due to flushing out $HbR$ via blood flow
#
# 6. With an artificial contrast agent injected, will MR-signal increase or decrease with
# increased neural activity relative to rest?
# > - it will decrease because of increased volume for contrast during NA
#
# 7. With blood as contrast agent, will MR-signal increase or decrease with increased
# neural activity relative to rest (after a few sec)? Why?
# > - It will increase because of flushing out $HbR$ It is because there is more oxygen supply that consumption, and there fore additional $HbO$ flow
# > <img  src="images/q3g3.png" width=400/>
# 8. Why does size matter (in terms of vascular size)? Think: Large veins versus
# capillaries, T2 and T2*, and gradient- vs. spin-echo sequences…
# > - Because big size (large veins) $\Rightarrow$ no changes in gradient shape, only changes in gradient magnitude, so effect in reversible $\Rightarrow$  effect on $T2^*$
# > - Capillaries $\Rightarrow$  changes in gradient shape and magnitude $\Rightarrow$  irreversible effect $\Rightarrow$  effect on $T2$
#
# 1. In primates: how much energy do postsynaptic processes, spiking activity, and
# resting potential approximately cost?
# > $75\%$

# %% [markdown]
# #### Questions 3
#
# 1. What are some examples for dissociations between BOLD signal and spiking
# activity?
# >  - rivalry  (LGN, V1) big changes in BOLD, spike - no changes
#     - attention (feedback) BOLD is very sensitive
#     - flicker (V1) LGN	keeps	responding, V1	stops	spiking,	but	keeps	receiving
#     synaptic	input
#     - serotonin (Reduction	of	MUA,	but	preservation	of	LFP	and	BOLD response.)
#     - Cerebellum:	inhibition	of	Purkinje-firing	through	parallel	fibers
# >   > <img  src="images/q3g1.png" width=600/>
# 3. Which factors impose spatial limits in fMRI resolution?
#
#
# 4. What does GLM stand for?
# > Generalized Linear Model
# 5. What is the general idea behind GLM?
# > We have different predictors $X_j$, and assume that our signal is weighted sum of these predictors and some  Gaussian noise $\varepsilon$
# > Our aim is to find weights $\beta$ that minimize least square error $S=\varepsilon^{T}\varepsilon=\sum_i (Y_i-\hat{Y_i})^2 $
# 6. What is the basic equation?
# > $Y=X\beta +\varepsilon = \hat{Y} +\varepsilon$
# 7. What are advantages of using a GLM analysis?
# > - any shape of expected time course (predictors are continuous)
# > - many predictors (you can add noise predictors to cancel them out)
#
# 8. Which other tests are special cases of a GLM?
# > one-sample t-tests, 2-sample t-tests, paired t-test, ANOVA, ANCOVA

# %% [markdown]
# #### Questions 4
#
# 1. Which factors impose **spatial limits** in fMRI resolution?
# > - we measure BOLD, not neuronal activity $\Rightarrow$ some vessels are not near neuronal activity, so we can't say where exactly is NA that caused this signal.
# 2. What is a block-design, or a event-related design? What are their advantages?
# > Block design - long duration of stimulus $\Rightarrow$ large amplitude of signal, **better** in most cases
# > <img  src="images/q4g1.png"/>
# > Event-related design - short duration of stimulus $\Rightarrow$ small amplitude of signal. Use only if you need it, because of experiment design (for example if you need stimulus be 	difficult	to	predict		for	the	subject)
# > <img  src="images/q4g3.png"/>
#
# 3. What are the upper and lower temporal constraints in fMRI experiments?
# > You shout separate the same conditions (1 condition in 16 seconds) and you
#   will filter slow frequencies, so you have to have not so long stimulus duration
#
# 4. List some factors that can cause temporal signal drifts in fMRI, and how you can
# you avoid them or deal with them during analysis.
# >Problems
# >     - Head motion
#        - coil TT
#        - heart
#        - breathing
#        - aliasing
#        - boredom / alertness (you give the task to avoid it)
# >
# >How to deal with it?
# >
# > - you take it in your Design Matrix (you have to measure):
#     - head
#     - heard
#     - breathing
#  - head motion (special pre processing)
#  - high-pass filter
#  - "global scaling"/ mean signal in design matrix
#
# 5. What is the "multiple comparisons" problem?
# >  We have a lot of false positive, because we do a lot of tests simultaneously
#
# 6. What are solutions to the multiple comparisons problem?
# > - Bonferoni (but you will see nothing)
#    - FWE (Family wise )(you have special dependences) so you have 7000 independent voxel and measurments. Then bonferoni.
#    - FDR (you measure ): set procent of of false positives of significant voxels. What do we can
#    - ROI analysis ()
#    - (small volume correction)
#    - Cluster analysis ( Refers to conjoint probability of voxel-cluster size AND minimal individual voxel
# p-value )
