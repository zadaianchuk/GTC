# %% [markdown]
# * [Lecture 1. Neurotransmitter receptors](#l1)
#     * [Part 1. Ionotropic receptors](#l1p1)
#     * [Part 2. Metabotropic receptors](#l1p2)
#     * [Part 3. Calcium as second messenger ](#l1p3)
#
#
# * [Lecture 2. GABA receptors](#l2)
#
#     * [Part 1. Ionotropic GABA-R](#l2p1)
#     * [Part 2. Metabotropic GABA-R](#l2p2)
#
#
# * [Lecture 3. Glutomate receptors](#l3)
#
#     * [Part 1. Ionotropic Glu-R ](#l3p1)
#     * [Part 2. NMDA-R](#l3p2)
#     * [Part 3. Metabotropic Glu-R](#l3p3)
#
# <!-- * [Lecture 4](#l4)
#     * [Part 1. Introduction](#l4p1)
#     * [Part 2.  Quantum release](#l4p2)
#     * [Part 3. Culcium in NT ](#l4p3)
#     * [Part 4. Molecular mechanism of NT. ](#l4p4)
# * [Lecture 5](#l5)
#     * [Part 1. How NT cause EPSP](#l5p1)
#     * [Part 2. Molecular mechanism](#l5p2)
#     * [Part 3. GABA and Glutamate receptors ](#l5p3)
#     * [Part 4. Electrical synapse](#l5p4)
#
# * [Lecture 6](#l6)
#     * [Part 1. Introduction](#l6p1)
#     * [Part 2.  Long term synaptic plasticity](#l6p2)
#     * [Part 3. Sort term synaptic plasticity ](#l6p3)
#
# * [Lecture 7](#l7)
#
#     * [Part 1. Unit recording ](#l7p1)
#     * [Part 2.  Multiunit recording](#l7p2)
#     * [Part 3. Local field potential](#l7p3)
#     * [Part 4. Microstimulation](#l7p4)
#     * [Part 5. Optogenetics](#l7p5)
#     * [Part 6. Calcium imaging](#l7p6)
#     * [Part 7. Voltage sensitive dyes imaging](#l7p4) -->

# %% [markdown]
# <a id='l1'></a>
# ### Lecture 1.  Neurotransmitter receptors
#
# There are three major classes of cell-surface receptors:
# - **Ion-channel-linked receptors**
# - **G-protein-linked receptors**
# - Enzyme-linked receptors (signal molecule activate enzyme)

# %% [markdown]
# <a id='l1p1'></a>
# #### Part 1. Ionotropic receptors
#
# - **Ionotropic** (NT opens an ion channel) - **fast, short-lasting** synaptic transmission
# Example: ionotropic nACh-receptor
# >
# > - **5 protein sub-units**, each from **4 regions**.
# > - **M2** regions create pore.
# > ![](images/l1g1.png)
# > **2 molecules of $ACh$** in $\alpha_{\gamma}$ and $\alpha_{\delta}$ sites
# > ![](images/l1g4.png)
# > - **3 rings** of *negatively* charged amino acids (Glu-, Asp-)
# > ![](images/l1g2.png)
# >
# > Binding of $ACh$ $\rightarrow$ rotation (conformational change) $\rightarrow$ opened state
# > ![](images/l1g3.png)

# %% [markdown]
# <a id='l1p2'></a>
# #### Part 2. Metabotropic receptors
#
# - **Metabotropic** NT receptor (NT triggers intracellular processes) - **slow, long-lasting**
#
# Classification (by binding)
# >  1. Binding site **inside the membrane**
# >  2. Binding site on the **surface of membrane**
# >  3. Binding site inside **long N-terminal** (venus flytrap module - **VFTM**)
# ![](images/l1g5.png)
#
# Process:
#
# >Ligand binding $\rightarrow$ Conformational change $\rightarrow$ Binding & activation of G-protein
#
# Activation of G-protein:
#
# >Activated $\alpha$ (with [GTP][1]) and $\beta \gamma$-subunits unbind from receptor $\rightarrow$ $\alpha$ (with GTP) binding to target protein and activate it $\rightarrow$ $\alpha$-subunit unbinds from target protein via energy from hydrolysis of GTP (GTP $\rightarrow$ [GDP][2]) $\rightarrow$ binding of $\alpha$ and $\beta \gamma$-subunits $\rightarrow$ inactivated G-protein.
#
# Amplification:
#
# >- G-protein $\rightarrow$ $10^{10}$ [Glycogen molecules][3]
# - One Rodopsin molecule $\rightarrow$ many $250 Na^+$ channels closed (rod cell hyperpolorized by $1 mV$)
#
# Activation of different processes(**coordinated modulation**):
#
# >- altered metabolism
# - altered gene expression
# - altered cell shape and movement
# >
# Can be interaction between different processes triggered by second messengers (**crosstalk**)
#
# [1]:https://en.wikipedia.org/wiki/Guanosine_triphosphate
# [2]:https://en.wikipedia.org/wiki/Guanosine_diphosphate
# [3]:https://en.wikipedia.org/wiki/Glycogen

# %% [markdown]
# <a id='l1p3'></a>
# #### Part 3. Calcium as second messenger
#
# Functions
# >In neurons
# - [neurotransmitter release][0] at the chemical synapse
# - gatingb of ion channels ( $Cl^-_{Ca}, K^+_{Ca}, Ca^{2+}_{Ca}$)
# - [gating of Ryanodin- and IP3-receptors][2] ($Ca^{2+}$-induced $Ca^{2+}$-release)
# - activation of various enzymes: $Ca^{2+}$-calmodulin, $Ca^{2+}$-protein kinases
# - activation of transcription factors – **gene expression**
# - involvement in ‘synaptic plasticity’ – [**LTP**][1]
#
# > In muscle cells
# - electromechanical coupling – $Ca^{2+}$-binding to troponin C (de-blockade of a-m-binding) ???
# - heart muscle cells: delayed $Ca^{2+}$-influx – prolongation of AP‘s
#
# Related problems
# >- increased $[Ca^{2+}]_{int}$ is neurotoxic ! (Glu NMDA-rec.)
# -  dysregulation of $Ca^{2+}$ can lead to various pathologies
#
#
# $Ca^{2+}$-compartments
# > $[Ca^{2+}]_{int}$ is very small and can change in 1000 times. So it have to be regulated precisely in space and time.
#
# > <img  src="images/l1g6.png" width=400/>
#
# <a id='ryanodine'></a>
# Getting in
# >  - by voltage dependent channels
#       - L-type: high voltage, slow inactivation, inactivated by $Ca^{2+}$
#       - P/Q-types: high, slow, yes/no
#       - N-type: high, fast, yes
#       - R-type: high, fast, no
#       - T-type: **low **, very fast, no
#
# >   - by release from **intracellular stores** into the cytosol.(Ryanodine- und IP3-receptors)
# > <img  src="images/l1g7.png" width=500/>
#
# Getting out
# > <img  src="images/l1g8.png" width=500/>
# > $Ca^{2+}$-binding **proteins **: parvalbumine, calbindine (cytosol)
# calsequestrine (SER)
#
# >Mechanisms of $Ca^{2+}$-buffering
# - $Na^+-Ca^{2+}$-**transporter** in plasma membrane: **high capacity - low affinity** (to quickly remove $Ca^{2+}$ when the concentration is big)
# - $H^+-Ca^{2+}$- in mitochondria **transporter**: **high capacity - low affinity**
# >
# >- $Ca^{2+}$-ATPase **pump**: **low capacity - high affinity** (works even when there is small $[Ca^{2+}]$)
#   - PMCA: plasma membrane $Ca^{2+}$-pump
#   - SERCA: smooth endoplasmic reticulum $Ca^{2+}$-pump
#   - MMCA: mitochondrial membrane $Ca^{2+}$-pump
#
# [0]: ..\neurophisiology\neurophysiology.ipynb#l4p3
# [1]: ..\neurophisiology\neurophysiology.ipynb#l6p2
# [2]: #ryanodine

# %% [markdown]
# <a id='l2'></a>
# ### Lecture 2. GABA-receptors

# %% [markdown]
# <a id='l2p1'></a>
# #### Part 1. Ionotropic GABA-receptors (GABA$_A$ and GABA$_C$)
#
# Properties
#
# > - GABA$_A$- and GABA$_C$-R are anion channels
# > - they have conductance for Cl- (influx)
# > - M2 forms the pore – „selectivity filter“
# > - M2 has rings of positive charge (Lys+, Arg+)
# > - the $\beta$-subunit binds GABA ($\alpha$-subunit help a little)
# > - needed 2 GABA molecules
# > - GABA$_A$-R bind additional substances(**they modulate the channel properties**)
#
# Modulation of GABA$_A$-receptors (GABA$_C$ doesn't have such properties )
# > benzodiazepine binding (only with $\gamma$-subunit and only $\alpha_1$ has high affinity )
# > <img  src="images/l2g2.png" width=300/>
# > Experiment: Potentiation of GABA$_A$-receptor currents
# >>1. transfection of Xenopus oocytes with cDNAs of a-, b-, g-subunits
# 2. recordings with whole-cell patch-clamp technique
# 3. application of GABA alone
# 4. co-application of GABA + benzodiazepines (diazepam - DZP, FNZM)
# 5. co-application von GABA + barbiturates (pentobarbital - PB)
# >> <img  src="images/l2g3.png" width=700/>
# > Result: benzodiazepines and  barbiturates induce **more inhibition**
# > The same result we can obtain by stimulation of GABA-ergic interneurons (pre-synapt.)
# in the **hippocampus** brain slice preparation
# > <img  src="images/l2g4.png" width=400/>
# > So we see **potentiation of IPSP.**

# %% [markdown]
# <a id='l2p2'></a>
# #### Part 2. Metabotrophic GABA-receptors (GABA$_B$ )
#
# Properties
# > - 2 types: GABA$_B$1a-d and GABA$_B$2a-c (only 35% sequence homology)
#   - B1 / B2 are “co-distributed” in the brain (are even expressed in the same cells)
#   - expressed in all brain areas
#   - GABA$_A$-R vs. GABA$_B$-R: 50% / 50%
#   - in brainstem, thalamus, cerebellum, spinal cord: 90% GABA$_B$-R
#   - pre-, post- und extra-synaptically located
#
# GABA$_B$-R form heterodimers
# > - B1 and B2 work together and have different functions (B1 ligand binding, B2 G-protein binding)
# >  <img  src="images/l2g5.png" width=400/>
#
# GABA$_B$-receptor: effector systems
# >- GABA$_B$-receptor binds i/o-G proteins, that have such effect:
# > <img  src="images/l2g7.png" width=600/>
# >
# > Post-synaptical ($\alpha$-subunit):
# >> Activation of GABA$_B$-R post-synaptically activ. Gi/Go $\alpha$-SU inhibits AC $\rightarrow$ reduction of cAMP-level $\rightarrow$reduction of cAMP-dependent processes $\rightarrow$ reduction of protein kinase A-level ([PKA][1]) $\rightarrow$ no PKA – **no phosphorylation**
# >
# >Post-synaptical ($\beta \gamma$-subunit):
# >> activ. GABA$_B$-R post-synaptically $\rightarrow$ activ. Gi/Go (separation of $\alpha$-SU + $\beta \gamma$-SU) $\rightarrow \beta \gamma$-SU binds to $K^+$-channel (GirK) $\rightarrow$ gating: $K^+$ outflow  $\rightarrow$ **hyperpolarisation**
# >
# >Pre-synaptic effector systems (can be done by GABA released by the same synapse (**auto receptor**), or by other neuron that inhibit synapse (**hetero receptor**) )
# >> activ. GABA$_B$-R post-synaptically $\rightarrow$ activ. Gi/Go (separation of $\alpha$-SU + $\beta \gamma$-SU) $\rightarrow$
# $\beta \gamma$-SU binds to voltage gated $Ca^{2+}$ channels $\rightarrow$ modifies voltage dependence $\rightarrow$
# no gating – no/reduced $Ca^{2+}$-influx in pre-synapse $\rightarrow$ **no/reduced transmitter-release**
#
# Time course
# > <img  src="images/l2g8.png" width=700/>
#
# Summury
# > <img  src="images/l2g9.png" width=800/>
#
# [1]: https://en.wikipedia.org/wiki/Protein_kinase_A

# %% [markdown]
# <a id='l3'></a>
# ### Lecture 3. Glutamate receptors

# %% [markdown]
# <a id='l3p1'></a>
# #### Part 1. Ionotropic Glu-receptors (AMPA-Kainat-R, NMDA-R)
#
# Properties
# > - iGlu-Rs have been ‘pharmacologically’ differentiated based on their
# specific **synthetic agonists** and **antagonists**
# > - iGlu-Rs have different molecular structure (3 transmembrane domains
# + **1 pore-element**)
# > <img  src="images/l3g1.png" width=400/>
# > - They first assemble to form a
# dimer, then two dimers form a tetramer
# >  <img  src="images/l3g2.png" width=500/>
#
# Ligand binding
# > - Ligand binding occurs in the
# cleft formed by lobe I + lobe II.
# The two lobes are collectively
# formed by the extracellular
# loops.
# > <img  src="images/l3g3.png" width=400/>
# > - 4 Glu to one iGlu-R
# > - Glu binding and subsequent conformational change causes **tension** between dimers
# > - **affinity** of the dimer-interfaces determines the **inactivation** (desensitization):
# >  <img  src="images/l3g4.png" width=700/>
# > - high affinity -> fast inactivation -> small current (iGlu-R **flop**)
# > - weak affinity -> slow inactivation -> large current (iGlu-R **flip**)

# %% [markdown]
# <a id='l3p2'></a>
# #### Part 2. NMDA
#
# We need two receptors to activate NMDA
# > - **Glycine** (or ‘D-serine’) is bound by NR1 subunits (S1-S2-half domains)
# > - **Glutamate** is bound by NR2 subunits (S1-S2-half domains)
#
# Other properties:
# > - NMDA-Rs are cation channels with **high Ca2+-conductance**
# >   - play a major role in „synaptic plasticity“
# >   - play a role in „glutamate-toxicity“ – [Ca2+] (when glutomate stay in extracellular space -> too many Ca2+)
# > - NMDA-Rs are „ligand gated“ and **„voltage gated“**
# >  - gating requires [pre-depolarization][1] – removes ‘Mg2+-block’(accomplished by fast AMPA-Rs) )
# > - NMDA-Rs open and close ‘slowly’ – **late EPSP phase**
# > - NMDA-Rs have several **modulatory** binding sites  (hallucinogenic drugs(PCP), MK801, Ketamine, polyamines, pH (H$^+$))
#
# Experiment:
# >To check that NMDA-Rs close slowly, we can block it and look for difference
# > <img  src="images/l3g8.png" width=500/>
# > Useful table for such experiments
# > <img  src="images/l3g7.png" width=300/>
#
# NMDA-R subunits and channel properties
# > - functional channels are hetero-tetramers
# > - they consist of NR1 -+ NR2-subunits (type of NR2 is important for functions)
# > <img  src="images/l3g5.png" width=500/>
# > - NR1-NR3B-heteromers form cation channels which are gated by glycine alone.
# (excitatory glycine receptor, no Ca2+-conductance, no Mg2+-block, expressed in the
# spinal cord )
#
#
#
# Summary
# > <img  src="images/l3g6.png" width=700/>
# [1]:..\neurophisiology\neurophysiology.ipynb#l5p3

# %% [markdown]
# <a id='l3p3'></a>
# #### Part 3. Metabotropic Glu-R

# %% [markdown]
# #### Signal Transduction - General
#
# Ionotropic vs. metabotropic receptors:
# - General molecular composition of these receptor types.
# - Difference between cation vs. anion channels (ACh-/GABA$_A$-rec.).
# - General features of ionotropic vs. metabotropic receptors (time
# course, effects, duration of effects, amplification, cross-talk).
# - Metabotropic receptor: signal transduction from extracellular to
# intracellular – sec. mess. cascades – ‘long’ vs. ‘short’ cascades.
#
# $Ca^{2+}$ functions in excitable cells
# - Name a few functions of $Ca^{2+}$ in neurons …
# - Name the major structures/mechanisms by which $Ca^{2+}$  enters the
# cytoplasm.
# - Mechanisms by which $Ca^{2+}$ action is ceased/buffered and
# mechanisms of $Ca^{2+}$  removal.

# %% [markdown]
# #### GABA receptors
# GABA$_A$-receptors
# - Subunits / subunit composition – function …
# - Distinctive features of GABAA-receptors – pharmacology.
# - Physiological effect of GABAA activation.
# - Potentiation of GABAA-currents.
#
# GABA$_B$-receptors
# - Molecular composition / VFTM / hetero-dimer.
# - Occurrence in the CNS.
# - Second messenger coupling:
#     - Pre-synaptic localization – effect (in detail).
#     - Post-synaptic localization – effect (in detail)

# %% [markdown]
# #### Glutamate Receptors
# Ionotropic glutamate-receptors
# - Molecular composition – gating / compare.
# - Characterize the two classes of iGlu-receptors.
# - Major function of AMPA-receptors.
# - Distinctive features of NMDA-receptors (in detail).
#  - Gating mechanisms / major function.
#
# Metabotropic glutamate-receptors
# - 8 types – 3 groups / how are the “Groups” characterized?
# - Second messenger coupling Group II and III.
# - Second messenger coupling Group I (in detail).
# - Occurrence of mGlu-Rs in the CNS.

# %% [markdown]
# Questions
#
# Lecture 1. What is the function of rapsyn?

# %% [markdown]
# ### Lecture 8. Glia

# %% [markdown]
# <!--Mircoglia - from mesemchymal cells, travel from blood and became mircoglia
#
# Astrocytes -
#
# apoltosis (delete neurons that are not needed in the development)
#
# supply energy
#
# modulation of synaptic transmission
#
# homeostasis - take care of balance of differt ions, whater, pH
#
# Depending of contact site :
#  - neighboring astrocytes
#  - pia
#  - blood
#  - synapses
#
# They express different things:
#  - -->
